# %%
import pandas as pd 
oil_final = pd.read_csv("C:/Users/Sung/Desktop/Opinet_Data/주유소_부가정보/opinet_final.csv", encoding= "cp949")

# %%
oil_add_info = pd.read_csv("C:/Users/Sung/Desktop/Opinet_Data/주유소_부가정보/oil_add_info.csv", encoding= "cp949")

# %%
oil_final_raw = pd.DataFrame({"sigunm" : oil_final["지역"],
                         "os_nm": oil_final["상호"],
                         "new_adr": oil_final["주소"],
                         "trade_dt": oil_final["기간"],
                         "oil_price": oil_final["휘발유"],
                         "poll_div_cd": oil_final["상표"],
                         "self_yn": oil_final["셀프여부"]})
oil_final_raw.head()
# Out:
#    sigunm          os_nm                new_adr  trade_dt  oil_price  \
# 0  강원 강릉시    (주)동해에너지주유소   강원 강릉시 경강로 2101(임당동)  20200909       1330
# 1  강원 강릉시    (주)동해에너지주유소   강원 강릉시 경강로 2101(임당동)  20200910       1330
# 2  강원 강릉시  (주)명진에너지 사천지점  강원도 강릉시 사천면 동해대로 3576  20200909       1339
# 3  강원 강릉시  (주)명진에너지 사천지점  강원도 강릉시 사천면 동해대로 3576  20200910       1339
# 4  강원 강릉시  (주)삼보물류 삼보주유소       강원 강릉시 동해대로 3970  20200909       1347
#
#   poll_div_cd self_yn
# 0       SK에너지      셀프
# 1       SK에너지      셀프
# 2       SK에너지      셀프
# 3       SK에너지      셀프
# 4       S-OIL      일반

# %%
oil_final_raw[oil_final_raw["new_adr"] == ' ']
# Out:
#           sigunm              os_nm new_adr  trade_dt  oil_price poll_div_cd  \
# 3011225   경북 구미시       낙동강구미주유소/충전소          20191222       1495       SK에너지
# 3022677   경북 구미시       낙동강구미주유소/충전소          20191221       1495       SK에너지
# 3034150   경북 구미시       낙동강구미주유소/충전소          20191220       1495       SK에너지
# 3045633   경북 구미시       낙동강구미주유소/충전소          20191219       1492       SK에너지
# 3057112   경북 구미시       낙동강구미주유소/충전소          20191218       1490       SK에너지
# ...          ...                ...     ...       ...        ...         ...
# 24421106  충북 청원군  현대오일뱅크㈜직영 오창산단주유소          20150101       1485       S-OIL
# 24421107  충북 청원군              현대주유소          20150101       1569      현대오일뱅크
# 24421108  충북 청원군              현도주유소          20150101       1529      현대오일뱅크
# 24421109  충북 청원군              호반주유소          20150101       1599       S-OIL
# 24421110  충북 청원군             화진1주유소          20150101       1625       S-OIL
#
#          self_yn
# 3011225       일반
# ...

# %%
oil_final_raw[oil_final_raw["new_adr"] != ' ']
# Out:
#           sigunm          os_nm                   new_adr  trade_dt  \
# 0         강원 강릉시    (주)동해에너지주유소      강원 강릉시 경강로 2101(임당동)  20200909
# 1         강원 강릉시    (주)동해에너지주유소      강원 강릉시 경강로 2101(임당동)  20200910
# 2         강원 강릉시  (주)명진에너지 사천지점     강원도 강릉시 사천면 동해대로 3576  20200909
# 3         강원 강릉시  (주)명진에너지 사천지점     강원도 강릉시 사천면 동해대로 3576  20200910
# 4         강원 강릉시  (주)삼보물류 삼보주유소          강원 강릉시 동해대로 3970  20200909
# ...          ...            ...                       ...       ...
# 24421329  충북 충주시   화령개발(주)공단주유소  충청북도 충주시  국원대로 370 (목행동)  20150101
# 24421330  충북 충주시          화원주유소       충북 충주시 소태면 구룡로 1060  20150101
# 24421331  충북 충주시          황금주유소        충북 충주시 엄정면 구룡로 396  20150101
# 24421332  충북 충주시          황제주유소      충북 충주시 신니면 중원대로 5775  20150101
# 24421333  충북 충주시          희망주유소           충북 충주시 금봉대로 398  20150101
#
#           oil_price poll_div_cd self_yn
# 0              1330       SK에너지      셀프
# 1              1330       SK에너지      셀프
# ...

# %%
oil_final_raw = oil_final_raw[oil_final_raw["new_adr"] != ' ']

# %%
del oil_add_info["Unnamed: 0"]
oil_add_info.head()
# Out:
#     sido  si   gu             os_nm                    new_adr  \
# 0  서울특별시  서울  강남구       (주)보성 세곡주유소      서울 강남구  헌릉로 731 (세곡동)
# 1  서울특별시  서울  강남구          오일프러스 셀프    서울 강남구 남부순환로 2651 (도곡동)
# 2  서울특별시  서울  강남구    현대오일뱅크 도곡셀프주유소  서울 강남구  남부순환로 2718 (도곡2동)
# 3  서울특별시  서울  강남구  GS칼텍스(주)직영 산성주유소             서울 강남구 헌릉로 730
# 4  서울특별시  서울  강남구             방죽주유소      서울 강남구 밤고개로 215 (율현동)
#
#                api_adr poll_div_cd self_yn wash_yn repair_yn conv_yn all24_yn
# 0     서울 강남구  헌릉로 731        SK에너지       Y       Y         N       N        N
# 1   서울 강남구 남부순환로 2651        SK에너지       Y       Y         Y       N        Y
# 2  서울 강남구  남부순환로 2718       현대오일뱅크       Y       Y         Y       N        N
# 3       서울 강남구 헌릉로 730       GS칼텍스       Y       Y         N       N        N
# 4     서울 강남구 밤고개로 215        S-OIL       Y       Y         N       N        N

# %%
oil_add_info["si"].unique()
# Out:
# array(['서울', '경기', '부산', '대구', '인천', '광주', '대전', '울산', '세종', '강원', '충북',
#        '충남', '전북', '전남', '경북', '경남', '제주'], dtype=object)

# %%
oil_add_info[oil_add_info["si"]== "세종"]
# Out:
#          sido  si       gu                os_nm                  new_adr  \
# 1812  세종특별자치시  세종     다정북로              아성알뜰주유소          세종특별자치시 다정북로 40
# 1813  세종특별자치시  세종  국책연구원3로           세종알뜰주유소(주)        세종특별자치시 국책연구원3로 9
# 1814  세종특별자치시  세종      세종로   대영에너지㈜세종지점 다온알뜰주유소   세종특별자치시 세종로 1328 (아름동)
# 1815  세종특별자치시  세종     마음안로            고운self주유소  세종특별자치시 마음안로 136  (고운동)
# 1816  세종특별자치시  세종     조치원읍               베스트주유소         세종 조치원읍 세종로 2749
# 1817  세종특별자치시  세종     조치원읍                그린주유소         세종 조치원읍 세종로 2706
# 1818  세종특별자치시  세종     조치원읍                신원주유소         세종 조치원읍 세종로 2562
# 1819  세종특별자치시  세종      연서면                봉암주유소         세종시 연서면 세종로 1899
# 1820  세종특별자치시  세종      어울로                새롬주유소         세종시 어울로 77 (새롬동)
# 1821  세종특별자치시  세종     보듬5로      지에스칼텍스㈜ 세종청사주유소           세종특별자치시 보듬5로 6
# 1822  세종특별자치시  세종      전의면               세종로주유소          세종 전의면 세종로 3880
# 1823  세종특별자치시  세종      전동면                석곡주유소        세종 전동면 하석곡길 64-10
# ...

# %% [markdown]
# # 시 정보 붙이기

# %%
# 구 이름 추출 
oil_final_raw['si']  = [eachAddress.split(" ")[0] for eachAddress in oil_final_raw["sigunm"]]

# %%
oil_final_raw["si"].unique()
# Out:
# array(['강원', '경기', '경남', '경북', '광주', '대구', '대전', '부산', '서울', '세종시', '울산',
#        '인천', '전남', '전북', '제주', '충남', '충북'], dtype=object)

# %%
oil_final_raw[oil_final_raw["si"] == '세종시']
# Out:
#          sigunm           os_nm            new_adr  trade_dt  oil_price  \
# 14192       세종시  (주)동강상사 소나무주유소    세종 전의면 세종로 3907  20200909       1305
# 14193       세종시  (주)동강상사 소나무주유소    세종 전의면 세종로 3907  20200910       1305
# 14194       세종시           (주)명성   세종 조치원읍 세종로 2210  20200909       1418
# 14195       세종시           (주)명성   세종 조치원읍 세종로 2210  20200910       1418
# 14196       세종시  (주)한유에너지 중부주유소  세종시 조치원읍 세종로 2167  20200909       1529
# ...         ...             ...                ...       ...        ...
# 24416934    세종시           행복주유소  세종시 부강면 시목부강로 423  20150101       1609
# 24416935    세종시    현대오일뱅크 대일주유소    세종 연서면 세종로 2137  20150101       1689
# 24416936    세종시         홍대셀프주유소  세종시 조치원읍 세종로 2654  20150101       1609
# 24416937    세종시           황용주유소     세종 금남면 황용1길 40  20150101       1628
# 24416938    세종시           흥진주유소   세종 조치원읍 신안새동네길 4  20150101       1578
#
#          poll_div_cd self_yn   si
# 14192           자가상표      일반  세종시
# ...

# %%
sejong = oil_final_raw[oil_final_raw["si"] == '세종시']
sejong['gu']  = [eachAddress.split(" ")[1] for eachAddress in sejong["new_adr"]]
# Out:
# <ipython-input-14-da6c74cd0018>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sejong['gu']  = [eachAddress.split(" ")[1] for eachAddress in sejong["new_adr"]]

# %%
sejong
# Out:
#          sigunm           os_nm            new_adr  trade_dt  oil_price  \
# 14192       세종시  (주)동강상사 소나무주유소    세종 전의면 세종로 3907  20200909       1305
# 14193       세종시  (주)동강상사 소나무주유소    세종 전의면 세종로 3907  20200910       1305
# 14194       세종시           (주)명성   세종 조치원읍 세종로 2210  20200909       1418
# 14195       세종시           (주)명성   세종 조치원읍 세종로 2210  20200910       1418
# 14196       세종시  (주)한유에너지 중부주유소  세종시 조치원읍 세종로 2167  20200909       1529
# ...         ...             ...                ...       ...        ...
# 24416934    세종시           행복주유소  세종시 부강면 시목부강로 423  20150101       1609
# 24416935    세종시    현대오일뱅크 대일주유소    세종 연서면 세종로 2137  20150101       1689
# 24416936    세종시         홍대셀프주유소  세종시 조치원읍 세종로 2654  20150101       1609
# 24416937    세종시           황용주유소     세종 금남면 황용1길 40  20150101       1628
# 24416938    세종시           흥진주유소   세종 조치원읍 신안새동네길 4  20150101       1578
#
#          poll_div_cd self_yn   si    gu
# 14192           자가상표      일반  세종시   전의면
# ...

# %%
notsejong = oil_final_raw[oil_final_raw["si"] != '세종시']
notsejong['gu']  = [eachAddress.split(" ")[1] for eachAddress in notsejong["sigunm"]]
# Out:
# <ipython-input-16-58fab2d48be3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   notsejong['gu']  = [eachAddress.split(" ")[1] for eachAddress in notsejong["sigunm"]]

# %%
sejong.head()
# Out:
#       sigunm           os_nm            new_adr  trade_dt  oil_price  \
# 14192    세종시  (주)동강상사 소나무주유소    세종 전의면 세종로 3907  20200909       1305
# 14193    세종시  (주)동강상사 소나무주유소    세종 전의면 세종로 3907  20200910       1305
# 14194    세종시           (주)명성   세종 조치원읍 세종로 2210  20200909       1418
# 14195    세종시           (주)명성   세종 조치원읍 세종로 2210  20200910       1418
# 14196    세종시  (주)한유에너지 중부주유소  세종시 조치원읍 세종로 2167  20200909       1529
#
#       poll_div_cd self_yn   si    gu
# 14192        자가상표      일반  세종시   전의면
# 14193        자가상표      일반  세종시   전의면
# 14194       GS칼텍스      일반  세종시  조치원읍
# 14195       GS칼텍스      일반  세종시  조치원읍
# 14196       SK에너지      일반  세종시  조치원읍

# %%
sejong.loc[sejong["si"] == "세종시", "si"] = "세종"
# Out:
# c:\users\sung\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
notsejong.head()
# Out:
#    sigunm          os_nm                new_adr  trade_dt  oil_price  \
# 0  강원 강릉시    (주)동해에너지주유소   강원 강릉시 경강로 2101(임당동)  20200909       1330
# 1  강원 강릉시    (주)동해에너지주유소   강원 강릉시 경강로 2101(임당동)  20200910       1330
# 2  강원 강릉시  (주)명진에너지 사천지점  강원도 강릉시 사천면 동해대로 3576  20200909       1339
# 3  강원 강릉시  (주)명진에너지 사천지점  강원도 강릉시 사천면 동해대로 3576  20200910       1339
# 4  강원 강릉시  (주)삼보물류 삼보주유소       강원 강릉시 동해대로 3970  20200909       1347
#
#   poll_div_cd self_yn  si   gu
# 0       SK에너지      셀프  강원  강릉시
# 1       SK에너지      셀프  강원  강릉시
# 2       SK에너지      셀프  강원  강릉시
# 3       SK에너지      셀프  강원  강릉시
# 4       S-OIL      일반  강원  강릉시

# %%
len(sejong) + len(notsejong) == len(oil_final_raw)
# Out:
# True

# %%
oil_final_raw = pd.concat([sejong, notsejong])

# %%
oil_final_raw
# Out:
#           sigunm           os_nm                   new_adr  trade_dt  \
# 14192        세종시  (주)동강상사 소나무주유소           세종 전의면 세종로 3907  20200909
# 14193        세종시  (주)동강상사 소나무주유소           세종 전의면 세종로 3907  20200910
# 14194        세종시           (주)명성          세종 조치원읍 세종로 2210  20200909
# 14195        세종시           (주)명성          세종 조치원읍 세종로 2210  20200910
# 14196        세종시  (주)한유에너지 중부주유소         세종시 조치원읍 세종로 2167  20200909
# ...          ...             ...                       ...       ...
# 24421329  충북 충주시    화령개발(주)공단주유소  충청북도 충주시  국원대로 370 (목행동)  20150101
# 24421330  충북 충주시           화원주유소       충북 충주시 소태면 구룡로 1060  20150101
# 24421331  충북 충주시           황금주유소        충북 충주시 엄정면 구룡로 396  20150101
# 24421332  충북 충주시           황제주유소      충북 충주시 신니면 중원대로 5775  20150101
# 24421333  충북 충주시           희망주유소           충북 충주시 금봉대로 398  20150101
#
#           oil_price poll_div_cd self_yn  si    gu
# 14192          1305        자가상표      일반  세종   전의면
# ...

# %%
lista = list(oil_final_raw["si"].unique())

# %%
lista1 = list(oil_final_raw["gu"].unique())

# %%
listb = list(oil_add_info["si"].unique())

# %%
listb1 = list(oil_add_info["gu"].unique())

# %%
setlista = set(lista)
setlistb = set(listb)

setlista1 = set(lista1)
setlistb1 = set(listb1)

# %%
print(setlista.difference(setlistb))
print(setlistb.difference(setlista))
# Out:
# set()
# set()

# %%
print(setlista1.difference(setlistb1))
print(setlistb1.difference(setlista1))
# Out:
# {'', '9국책연구원3로', '금남구즉로', '장군면'}
# {'음성', '구좌읍', '밀양', '광역시', '천안', '여주군'}

# %% [markdown]
# ---------------------------------------------------------------------

# %% [markdown]
# # 데이터 맞추기 (oil_final_raw, oil_add_info)

# %% [markdown]
# ### 1. {'여주군'} - 여주군 == 여주시

# %%
# oil_add_info.loc[oil_add_info["gu"] == "여주군"]
oil_add_info.loc[oil_add_info["gu"] == "여주군", "gu"] = '여주시'
# k = oil_final_raw[oil_final_raw["si"] == "경기"]
# print(k["gu"].unique())

# %% [markdown]
# ### 2. {'천안'} - 천안 == 천안시

# %%
oil_add_info.loc[oil_add_info["gu"] == "천안"]
# Out:
#       sido  si  gu          os_nm               new_adr               api_adr  \
# 6424  충청남도  충남  천안  삼미상사(주)북천안주유소  충남 천안 서북구 직산읍 군삼길 81  충남 천안 서북구 직산읍 군삼길 81
# 6425  충청남도  충남  천안  삼미상사(주)북천안주유소  충남 천안 서북구 직산읍 군삼길 81  충남 천안 서북구 직산읍 군삼길 81
#
#      poll_div_cd self_yn wash_yn repair_yn conv_yn all24_yn
# 6424       SK에너지       N       Y         N       N        N
# 6425       SK에너지       N       Y         N       N        N

# %%
k = oil_final_raw[oil_final_raw["si"] == "충남"]
print(k["gu"].unique())
# Out:
# ['계룡시' '공주시' '금산군' '논산시' '당진시' '보령시' '부여군' '서산시' '서천군' '아산시' '예산군' '천안시'
#  '청양군' '태안군' '홍성군']

# %%
oil_add_info.loc[oil_add_info["gu"] == "천안", "gu"] = '천안시'

# %% [markdown]
# ### 3. {'음성'} 음성 == 음성군

# %%
oil_add_info.loc[oil_add_info["gu"] == "음성"]
# Out:
#       sido  si  gu    os_nm            new_adr            api_adr poll_div_cd  \
# 5464  충청북도  충북  음성  삼성농협주유소  충북 음성 삼성면 대성로 543  충북 음성 삼성면 대성로 543      NH-OIL
#
#      self_yn wash_yn repair_yn conv_yn all24_yn
# 5464       Y       Y         N       N        N

# %%
k = oil_final_raw[oil_final_raw["si"] == "충북"]
print(k["gu"].unique())
# Out:
# ['괴산군' '단양군' '보은군' '영동군' '옥천군' '음성군' '제천시' '증평군' '진천군' '청주시' '충주시']

# %%
oil_add_info.loc[oil_add_info["gu"] == "음성", "gu"] = '음성군'

# %% [markdown]
# ### 4. { '밀양'} 밀양 == 밀양시

# %%
oil_add_info.loc[oil_add_info["gu"] == "밀양"]
# Out:
#       sido  si  gu     os_nm            new_adr            api_adr  \
# 8671  경상남도  경남  밀양  (주)천하주유소  경남 밀양 부북면 제대2길 14  경남 밀양 부북면 제대2길 14
#
#      poll_div_cd self_yn wash_yn repair_yn conv_yn all24_yn
# 8671       S-OIL       N       Y         N       N        N

# %%
k = oil_final_raw[oil_final_raw["si"] == "경남"]
print(k["gu"].unique())
# Out:
# ['거제시' '거창군' '고성군' '김해시' '남해군' '밀양시' '사천시' '산청군' '양산시' '의령군' '진주시' '창녕군'
#  '창원시' '통영시' '하동군' '함안군' '함양군' '합천군']

# %%
oil_add_info.loc[oil_add_info["gu"] == "밀양", "gu"] = '밀양시'

# %% [markdown]
# ### 5. {'구좌읍'}

# %%
oil_add_info.loc[oil_add_info["gu"] == "구좌읍"]
# Out:
#          sido  si   gu  os_nm                new_adr                api_adr  \
# 9323  제주특별자치도  제주  구좌읍  대천주유소  제주특별자치도 구좌읍 비자림로 1219  제주특별자치도 구좌읍 비자림로 1219
#
#      poll_div_cd self_yn wash_yn repair_yn conv_yn all24_yn
# 9323      현대오일뱅크       N       N         N       Y        N

# %%
k = oil_final_raw[oil_final_raw["si"] == "제주"]
print(k["gu"].unique())
# Out:
# ['서귀포시' '제주시']

# %%
oil_final_raw[(oil_final_raw["os_nm"] == '대천주유소') & (oil_final_raw["si"] == '제주')]
# Out:
#           sigunm  os_nm                new_adr  trade_dt  oil_price  \
# 19159     제주 제주시  대천주유소  제주특별자치도 구좌읍 비자림로 1219  20200909       1430
# 19160     제주 제주시  대천주유소  제주특별자치도 구좌읍 비자림로 1219  20200910       1430
# 32383     제주 제주시  대천주유소  제주특별자치도 구좌읍 비자림로 1219  20200908       1430
# 43772     제주 제주시  대천주유소  제주특별자치도 구좌읍 비자림로 1219  20200907       1430
# 55151     제주 제주시  대천주유소  제주특별자치도 구좌읍 비자림로 1219  20200906       1430
# ...          ...    ...                    ...       ...        ...
# 24371442  제주 제주시  대천주유소  제주특별자치도 구좌읍 비자림로 1219  20150105       1560
# 24383307  제주 제주시  대천주유소  제주특별자치도 구좌읍 비자림로 1219  20150104       1560
# 24395343  제주 제주시  대천주유소  제주특별자치도 구좌읍 비자림로 1219  20150103       1560
# 24407403  제주 제주시  대천주유소  제주특별자치도 구좌읍 비자림로 1219  20150102       1560
# 24419453  제주 제주시  대천주유소  제주특별자치도 구좌읍 비자림로 1219  20150101       1560
#
#          poll_div_cd self_yn  si   gu
# 19159         현대오일뱅크      일반  제주  제주시
# 19160         현대오일뱅크      일반  제주  제주시
# ...

# %%
oil_add_info.loc[oil_add_info["gu"] == "구좌읍", "gu"] = '제주시'

# %% [markdown]
# ### 6. { '광역시'}

# %%
oil_add_info[oil_add_info["gu"] == "광역시"]
# Out:
#        sido  si   gu   os_nm             new_adr             api_adr  \
# 1645  대전광역시  대전  광역시  도서관주유소  대전 광역시 중구 보문산로 353  대전 광역시 중구 보문산로 353
#
#      poll_div_cd self_yn wash_yn repair_yn conv_yn all24_yn
# 1645      현대오일뱅크       Y       Y         N       N        N

# %%
k = oil_final_raw[oil_final_raw["si"] == "대전"]
print(k["gu"].unique())
# Out:
# ['대덕구' '동구' '서구' '유성구' '중구']

# %%
k[k["os_nm"] == "도서관주유소"]
# Out:
#          sigunm   os_nm             new_adr  trade_dt  oil_price poll_div_cd  \
# 12340     대전 중구  도서관주유소  대전 광역시 중구 보문산로 353  20200909       1284      현대오일뱅크
# 12341     대전 중구  도서관주유소  대전 광역시 중구 보문산로 353  20200910       1284      현대오일뱅크
# 28959     대전 중구  도서관주유소  대전 광역시 중구 보문산로 353  20200908       1284      현대오일뱅크
# 40361     대전 중구  도서관주유소  대전 광역시 중구 보문산로 353  20200907       1294      현대오일뱅크
# 51745     대전 중구  도서관주유소  대전 광역시 중구 보문산로 353  20200906       1294      현대오일뱅크
# ...         ...     ...                 ...       ...        ...         ...
# 24367846  대전 중구  도서관주유소  대전 광역시 중구 보문산로 353  20150105       1517       SK에너지
# 24379747  대전 중구  도서관주유소  대전 광역시 중구 보문산로 353  20150104       1517       SK에너지
# 24391721  대전 중구  도서관주유소  대전 광역시 중구 보문산로 353  20150103       1517       SK에너지
# 24403773  대전 중구  도서관주유소  대전 광역시 중구 보문산로 353  20150102       1517       SK에너지
# 24415824  대전 중구  도서관주유소  대전 광역시 중구 보문산로 353  20150101       1517       SK에너지
#
#          self_yn  si  gu
# ...

# %%
oil_final_raw.loc[oil_final_raw["gu"] == "광역시", "gu"] = '중구'

# %% [markdown]
# --------------------------------------------------------------------------
# > oil_add_info, oil_final_raw

# %% [markdown]
# ### ''

# %%
k = oil_final_raw.loc[oil_final_raw["gu"] == ""]
k
# Out:
#          sigunm  os_nm                new_adr  trade_dt  oil_price  \
# 24054691    세종시  광장주유소  세종특별자치시  소정면 세종로 4732  20150131          0
# 24066830    세종시  광장주유소  세종특별자치시  소정면 세종로 4732  20150130       1399
# 24078964    세종시  광장주유소  세종특별자치시  소정면 세종로 4732  20150129       1399
# 24091097    세종시  광장주유소  세종특별자치시  소정면 세종로 4732  20150128       1399
# 24103220    세종시  광장주유소  세종특별자치시  소정면 세종로 4732  20150127       1399
# 24115350    세종시  광장주유소  세종특별자치시  소정면 세종로 4732  20150126       1499
# 24127471    세종시  광장주유소  세종특별자치시  소정면 세종로 4732  20150125       1499
# 24139592    세종시  광장주유소  세종특별자치시  소정면 세종로 4732  20150124       1499
# 24151723    세종시  광장주유소  세종특별자치시  소정면 세종로 4732  20150123       1698
# 24163852    세종시  광장주유소  세종특별자치시  소정면 세종로 4732  20150122       1698
# 24175953    세종시  광장주유소  세종특별자치시  소정면 세종로 4732  20150121       1698
# 24188063    세종시  광장주유소  세종특별자치시  소정면 세종로 4732  20150120       1698
# 24200160    세종시  광장주유소  세종특별자치시  소정면 세종로 4732  20150119       1698
# ...

# %%
print(k["new_adr"].unique())
# Out:
# ['세종특별자치시  소정면 세종로 4732']

# %%
k = oil_add_info[oil_add_info["si"] == "세종"]
print(k["gu"].unique())
# Out:
# ['다정북로' '국책연구원3로' '세종로' '마음안로' '조치원읍' '연서면' '어울로' '보듬5로' '전의면' '전동면' '부강면'
#  '금송로' '갈매로' '소담로' '금남면' '다솜로' '연동면' '연기면' '소정면']

# %%
oil_final_raw.loc[oil_final_raw["gu"] == "", "gu"] = '소정면'

# %%
oil_final_raw.loc[oil_final_raw["gu"] == ""]
# Out:
# Empty DataFrame
# Columns: [sigunm, os_nm, new_adr, trade_dt, oil_price, poll_div_cd, self_yn, si, gu]
# Index: []

# %% [markdown]
# ### 9국책연구원3로 -> 잘못 기입됨 (원래는 국책원구원3로)

# %%
oil_final_raw[oil_final_raw["gu"] == "9국책연구원3로"]
# Out:
#         sigunm       os_nm             new_adr  trade_dt  oil_price  \
# 29928      세종시  세종알뜰주유소(주)  세종특별자치시 9국책연구원3로 9  20200908       1298
# 29929      세종시  세종알뜰주유소(주)  세종특별자치시 9국책연구원3로 9  20200909       1298
# 41325      세종시  세종알뜰주유소(주)  세종특별자치시 9국책연구원3로 9  20200907       1298
# 52708      세종시  세종알뜰주유소(주)  세종특별자치시 9국책연구원3로 9  20200906       1298
# 64089      세종시  세종알뜰주유소(주)  세종특별자치시 9국책연구원3로 9  20200905       1298
# ...        ...         ...                 ...       ...        ...
# 1329434    세종시  세종알뜰주유소(주)  세종특별자치시 9국책연구원3로 9  20200517       1159
# 1340881    세종시  세종알뜰주유소(주)  세종특별자치시 9국책연구원3로 9  20200516       1159
# 1352334    세종시  세종알뜰주유소(주)  세종특별자치시 9국책연구원3로 9  20200515       1159
# 1363787    세종시  세종알뜰주유소(주)  세종특별자치시 9국책연구원3로 9  20200514       1159
# 1375237    세종시  세종알뜰주유소(주)  세종특별자치시 9국책연구원3로 9  20200513       1159
#
#         poll_div_cd self_yn  si        gu
# 29928         알뜰주유소      셀프  세종  9국책연구원3로
# 29929         알뜰주유소      셀프  세종  9국책연구원3로
# ...

# %%
k = oil_add_info[oil_add_info["si"] == "세종"]
print(k["gu"].unique())
# Out:
# ['다정북로' '국책연구원3로' '세종로' '마음안로' '조치원읍' '연서면' '어울로' '보듬5로' '전의면' '전동면' '부강면'
#  '금송로' '갈매로' '소담로' '금남면' '다솜로' '연동면' '연기면' '소정면']

# %%
oil_final_raw.loc[oil_final_raw["gu"] == "9국책연구원3로", "gu"] = '국책연구원3로'

# %% [markdown]
# ### 금남구즉로

# %%
oil_final_raw.loc[oil_final_raw["gu"] == "금남구즉로"]
# Out:
#          sigunm    os_nm             new_adr  trade_dt  oil_price poll_div_cd  \
# 14248       세종시  보람셀프주유소  세종시 금남구즉로 19 (대평동)  20200909       1339      현대오일뱅크
# 14249       세종시  보람셀프주유소  세종시 금남구즉로 19 (대평동)  20200910       1339      현대오일뱅크
# 29918       세종시  보람셀프주유소  세종시 금남구즉로 19 (대평동)  20200908       1339      현대오일뱅크
# 41315       세종시  보람셀프주유소  세종시 금남구즉로 19 (대평동)  20200907       1339      현대오일뱅크
# 52698       세종시  보람셀프주유소  세종시 금남구즉로 19 (대평동)  20200906       1339      현대오일뱅크
# ...         ...      ...                 ...       ...        ...         ...
# 21664190    세종시  보람셀프주유소  세종시 금남구즉로 19 (대평동)  20150817       1548      현대오일뱅크
# 21676163    세종시  보람셀프주유소  세종시 금남구즉로 19 (대평동)  20150816       1548      현대오일뱅크
# 21688124    세종시  보람셀프주유소  세종시 금남구즉로 19 (대평동)  20150815       1548      현대오일뱅크
# 21700121    세종시  보람셀프주유소  세종시 금남구즉로 19 (대평동)  20150814       1548      현대오일뱅크
# 21712136    세종시  보람셀프주유소  세종시 금남구즉로 19 (대평동)  20150813       1548      현대오일뱅크
#
#          self_yn  si     gu
# ...

# %%
k = oil_add_info[oil_add_info["si"] == "세종"]
print(k["gu"].unique())
# Out:
# ['다정북로' '국책연구원3로' '세종로' '마음안로' '조치원읍' '연서면' '어울로' '보듬5로' '전의면' '전동면' '부강면'
#  '금송로' '갈매로' '소담로' '금남면' '다솜로' '연동면' '연기면' '소정면']

# %%
k["os_nm"].unique() # 보람셀프주유소 X
# Out:
# array(['아성알뜰주유소', '세종알뜰주유소(주)', '대영에너지㈜세종지점 다온알뜰주유소', '고운self주유소',
#        '베스트주유소', '그린주유소', '신원주유소', '봉암주유소', '새롬주유소', '지에스칼텍스㈜ 세종청사주유소',
#        '세종로주유소', '석곡주유소', '세종동부농협주유소', '평산주유소', 'SK에너지㈜ 가람셀프주유소',
#        '삼미상사(주)도담셀프주유소', 'SK에너지(주) 소담self주유소', '남세종농협주유소',
#        '현대오일뱅크(주)직영 청사셀프주유소', '금빛주유소', '동세종농협주유소', '대보산업(주)전의산업단지주유소',
#        '실광주유소', 'CJ대한통운㈜ 중부화물터미널주유소', '㈜비타민셀프 세종셀프주유소', 'SK행복주유소',
#        '나라주유소', '승덕주유소', '(주)한유에너지 중부주유소', '진영주유소', '태산주유소', '신안주유소',
#        '세종주유소'], dtype=object)

# %% [markdown]
# ### 장군면

# %%
oil_final_raw.loc[oil_final_raw["gu"] == "장군면"]
# Out:
#          sigunm    os_nm                new_adr  trade_dt  oil_price  \
# 14222       세종시  남양대영주유소    세종특별자치시 장군면 장기로 842  20200909       1389
# 14223       세종시  남양대영주유소    세종특별자치시 장군면 장기로 842  20200910       1389
# 14272       세종시    송학주유소  세종특별자치시 장군면 의당전의로 677  20200909       1380
# 14273       세종시    송학주유소  세종특별자치시 장군면 의당전의로 677  20200910       1380
# 14292       세종시    장기주유소  세종특별자치시 장군면 장척로 408-7  20200909       1379
# ...         ...      ...                    ...       ...        ...
# 24404866    세종시    송학주유소  세종특별자치시 장군면 의당전의로 677  20150102       1595
# 24404875    세종시    장기주유소  세종특별자치시 장군면 장척로 408-7  20150102       1574
# 24416896    세종시  남양대영주유소    세종특별자치시 장군면 장기로 842  20150101       1593
# 24416915    세종시    송학주유소  세종특별자치시 장군면 의당전의로 677  20150101       1595
# 24416924    세종시    장기주유소  세종특별자치시 장군면 장척로 408-7  20150101       1599
#
#          poll_div_cd self_yn  si   gu
# 14222         현대오일뱅크      셀프  세종  장군면
# 14223         현대오일뱅크      셀프  세종  장군면
# ...

# %%
p = oil_final_raw.loc[oil_final_raw["gu"] == "장군면"]
p["os_nm"].unique()
# Out:
# array(['남양대영주유소', '송학주유소', '장기주유소'], dtype=object)

# %%
k = oil_add_info[oil_add_info["si"] == "세종"]
print(k["gu"].unique())
print(k["os_nm"].unique())
# Out:
# ['다정북로' '국책연구원3로' '세종로' '마음안로' '조치원읍' '연서면' '어울로' '보듬5로' '전의면' '전동면' '부강면'
#  '금송로' '갈매로' '소담로' '금남면' '다솜로' '연동면' '연기면' '소정면']
# ['아성알뜰주유소' '세종알뜰주유소(주)' '대영에너지㈜세종지점 다온알뜰주유소' '고운self주유소' '베스트주유소' '그린주유소'
#  '신원주유소' '봉암주유소' '새롬주유소' '지에스칼텍스㈜ 세종청사주유소' '세종로주유소' '석곡주유소' '세종동부농협주유소'
#  '평산주유소' 'SK에너지㈜ 가람셀프주유소' '삼미상사(주)도담셀프주유소' 'SK에너지(주) 소담self주유소' '남세종농협주유소'
#  '현대오일뱅크(주)직영 청사셀프주유소' '금빛주유소' '동세종농협주유소' '대보산업(주)전의산업단지주유소' '실광주유소'
#  'CJ대한통운㈜ 중부화물터미널주유소' '㈜비타민셀프 세종셀프주유소' 'SK행복주유소' '나라주유소' '승덕주유소'
#  '(주)한유에너지 중부주유소' '진영주유소' '태산주유소' '신안주유소' '세종주유소']

# %%
oil_add_info[oil_add_info["os_nm"] == "남양대영주유소"] # 0
oil_add_info[oil_add_info["os_nm"] == "장기주유소"] #0
oil_add_info[oil_add_info["os_nm"] == "송학주유소"] #  세종시 아님
# Out:
#       sido  si   gu  os_nm                new_adr                api_adr  \
# 6502  충청남도  충남  청양군  송학주유소    충남 청양군 청양읍 충절로 1468    충남 청양군 청양읍 충절로 1468
# 6665  전라북도  전북  익산시  송학주유소    전북 익산시 고현로 27 (송학동)         전북 익산시 고현로 27
# 7003  전라북도  전북  정읍시  송학주유소  전북 정읍시 신태인읍 신태인중앙로 69  전북 정읍시 신태인읍 신태인중앙로 69
#
#      poll_div_cd self_yn wash_yn repair_yn conv_yn all24_yn
# 6502       S-OIL       N       Y         N       N        N
# 6665       S-OIL       Y       Y         N       N        N
# 7003       GS칼텍스       N       Y         N       N        N

# %% [markdown]
# # 둘이 merge

# %%
print(oil_final_raw.columns)
print(len(oil_final_raw))
# Out:
# Index(['sigunm', 'os_nm', 'new_adr', 'trade_dt', 'oil_price', 'poll_div_cd',
#        'self_yn', 'si', 'gu'],
#       dtype='object')
# 24389501

# %%
print(oil_add_info.columns)
print(len(oil_add_info))
# Out:
# Index(['sido', 'si', 'gu', 'os_nm', 'new_adr', 'api_adr', 'poll_div_cd',
#        'self_yn', 'wash_yn', 'repair_yn', 'conv_yn', 'all24_yn'],
#       dtype='object')
# 9813

# %%
m = set(oil_final_raw.columns)
n = set(oil_add_info.columns)

print(m.difference(n))
print(n.difference(m))
# Out:
# {'sigunm', 'oil_price', 'trade_dt'}
# {'all24_yn', 'sido', 'conv_yn', 'repair_yn', 'wash_yn', 'api_adr'}

# %%
oil_final_raw.sort_values(by = ["os_nm", "new_adr"])
oil_final_raw.head()
# Out:
#       sigunm           os_nm            new_adr  trade_dt  oil_price  \
# 14192    세종시  (주)동강상사 소나무주유소    세종 전의면 세종로 3907  20200909       1305
# 14193    세종시  (주)동강상사 소나무주유소    세종 전의면 세종로 3907  20200910       1305
# 14194    세종시           (주)명성   세종 조치원읍 세종로 2210  20200909       1418
# 14195    세종시           (주)명성   세종 조치원읍 세종로 2210  20200910       1418
# 14196    세종시  (주)한유에너지 중부주유소  세종시 조치원읍 세종로 2167  20200909       1529
#
#       poll_div_cd self_yn  si    gu
# 14192        자가상표      일반  세종   전의면
# 14193        자가상표      일반  세종   전의면
# 14194       GS칼텍스      일반  세종  조치원읍
# 14195       GS칼텍스      일반  세종  조치원읍
# 14196       SK에너지      일반  세종  조치원읍

# %%
oil_add_info.sort_values(by = ["os_nm", "new_adr"])
oil_add_info.head()
# Out:
#     sido  si   gu             os_nm                    new_adr  \
# 0  서울특별시  서울  강남구       (주)보성 세곡주유소      서울 강남구  헌릉로 731 (세곡동)
# 1  서울특별시  서울  강남구          오일프러스 셀프    서울 강남구 남부순환로 2651 (도곡동)
# 2  서울특별시  서울  강남구    현대오일뱅크 도곡셀프주유소  서울 강남구  남부순환로 2718 (도곡2동)
# 3  서울특별시  서울  강남구  GS칼텍스(주)직영 산성주유소             서울 강남구 헌릉로 730
# 4  서울특별시  서울  강남구             방죽주유소      서울 강남구 밤고개로 215 (율현동)
#
#                api_adr poll_div_cd self_yn wash_yn repair_yn conv_yn all24_yn
# 0     서울 강남구  헌릉로 731        SK에너지       Y       Y         N       N        N
# 1   서울 강남구 남부순환로 2651        SK에너지       Y       Y         Y       N        Y
# 2  서울 강남구  남부순환로 2718       현대오일뱅크       Y       Y         Y       N        N
# 3       서울 강남구 헌릉로 730       GS칼텍스       Y       Y         N       N        N
# 4     서울 강남구 밤고개로 215        S-OIL       Y       Y         N       N        N

# %%
add_final = pd.merge(oil_final_raw, oil_add_info, 
                     how = 'left',
                     left_on = ["si","gu","os_nm","new_adr","poll_div_cd","self_yn"],
                     right_on = ["si","gu","os_nm","new_adr","poll_div_cd","self_yn"])

# %%
len(add_final) == len(oil_final_raw)
# Out:
# True

# %%
len(add_final)
# Out:
# 24389501

# %%
add_final.head()
# Out:
#   sigunm           os_nm            new_adr  trade_dt  oil_price poll_div_cd  \
# 0    세종시  (주)동강상사 소나무주유소    세종 전의면 세종로 3907  20200909       1305        자가상표
# 1    세종시  (주)동강상사 소나무주유소    세종 전의면 세종로 3907  20200910       1305        자가상표
# 2    세종시           (주)명성   세종 조치원읍 세종로 2210  20200909       1418       GS칼텍스
# 3    세종시           (주)명성   세종 조치원읍 세종로 2210  20200910       1418       GS칼텍스
# 4    세종시  (주)한유에너지 중부주유소  세종시 조치원읍 세종로 2167  20200909       1529       SK에너지
#
#   self_yn  si    gu sido api_adr wash_yn repair_yn conv_yn all24_yn
# 0      일반  세종   전의면  NaN     NaN     NaN       NaN     NaN      NaN
# 1      일반  세종   전의면  NaN     NaN     NaN       NaN     NaN      NaN
# 2      일반  세종  조치원읍  NaN     NaN     NaN       NaN     NaN      NaN
# 3      일반  세종  조치원읍  NaN     NaN     NaN       NaN     NaN      NaN
# 4      일반  세종  조치원읍  NaN     NaN     NaN       NaN     NaN      NaN

# %%
add_final["wash_yn"].isnull()
# Out:
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
#             ...
# 24389496    True
# 24389497    True
# 24389498    True
# 24389499    True
# 24389500    True
# Name: wash_yn, Length: 24389501, dtype: bool

# %%
add_final[]
